# %%
import pricing
import model_calibration as model
import options as opt
import yfinance as yf
import numpy as np
import pandas as pd
from scipy.interpolate import griddata
from datetime import datetime
import matplotlib.pyplot as plt
import seaborn as sns
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
S0 = 100
K = 100
T = 1
r = 0.04
vol = 0.2
M = 100000

# %%
model.volatility_surface('GOOGL')
# Out:
#      maturity  strike  implied vol           vega
# 0    0.008219    75.0    30.000000   1.619662e+00
# 1    0.008219    95.0    30.000000   1.871193e+00
# 2    0.008219   100.0    30.000000   1.928809e+00
# 3    0.008219   105.0    30.000000   1.984603e+00
# 4    0.008219   110.0    30.000000   2.038693e+00
# ..        ...     ...          ...            ...
# 926  2.041096   340.0    32.802178  8.507482e-118
# 927  2.041096   350.0    33.789839  4.450800e-125
# 928  2.041096   360.0    32.417546  5.269913e-115
# 929  2.041096   370.0    33.236647  5.874463e-121
# 930  2.041096   380.0    32.996650  3.436195e-119
#
# [931 rows x 4 columns]

# %%
model.plot_volatility_surface('GOOGL')

# %%
model.plot_vega_surface('GOOGL')

# %%
model.plot_vega_heatmap('GOOGL')

# %%
model.plot_volatility_heatmap('GOOGL')
